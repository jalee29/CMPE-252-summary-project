# %% [markdown]
# # Domain Generalization

# %% [markdown]
# this experiment relies on testing our fine tuned model on different domain test data and comparing it to how other models do. we can copy the baseline comparison code and replace the data
