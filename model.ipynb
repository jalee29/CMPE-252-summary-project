# %%
import pandas as pd

# %% [markdown]
# #### Process Data

# %%
#read in dataset
arxiv_data = pd.read_parquet("test-00000-of-00001.parquet")
arxiv_data.head()

# %%
#make tiny test dataset
data_tiny_test = arxiv_data.head(100)
data_tiny_test
data_tiny_test.to_csv('test.csv')

# %%
#make tiny validation set
data_tiny_val = arxiv_data.iloc[200:250]
data_tiny_val.to_csv('val.csv')

# %% [markdown]
# #### Create Model

# %% [markdown]
# ```shell
# python run_summarization.py `
#      --model_name_or_path facebook/bart-base `
#      --do_train `
#      --do_eval `
#      --train_file ../test.csv `
#      --validation_file ../val.csv `
#      --output_dir ../test-summarization `
#      --per_device_train_batch_size=4 `
#      --per_device_eval_batch_size=4 `
#      --predict_with_generate `
#      --text_column article `
#      --summary_column abstract
# ```

# %% [markdown]
# #### Test Model

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
model_name = "Veekee/cmpe-252-summary-project"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

text = ""
inputs = tokenizer(text, return_tensors="pt")

outputs = model.generate(**inputs, max_new_tokens=50)
summary = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(summary)
