# %% [markdown]
# # Compression Ratio

# %% [markdown]
# we can test which ratio works best by getting example source texts and change the models max_length and min_length and compare this to other models
